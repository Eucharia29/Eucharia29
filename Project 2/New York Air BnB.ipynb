# %%
import pandas as pd
import re

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\Air BnB.csv", low_memory=False)
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  object
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
# converting data type and removing NaN from latitude 

df['latitude'] = pd.to_numeric(df['latitude'],errors='coerce')
df['latitude'] = df['latitude'].fillna(df['latitude'].mean())

print(df[['latitude','longitude']].isnull().sum())
print(df['latitude'].tail())
print(df['longitude'].tail())
# Out:
# latitude     0
# longitude    0
# dtype: int64
# 48890    40.67853
# 48891    40.70184
# 48892    40.81475
# 48893    40.75751
# 48894    40.76404
# Name: latitude, dtype: float64
# 48890   -73.94995
# 48891   -73.93317
# 48892   -73.94867
# 48893   -73.99112
# 48894   -73.98933
# Name: longitude, dtype: float64

# %%
# converting data type and removing NaN in Last_Review 
df['reviews_per_month'] = df['reviews_per_month'].fillna(0)

df['last_review'] = pd.to_datetime(df['last_review'],dayfirst=True,errors='coerce')
#df['last_review'] = df['last_review'].where(df['last_review'].notna(),"No Reviews")

print(df[['last_review', 'reviews_per_month']].isnull().sum())
print(df['last_review'].head())
# Out:
# last_review          10052
# reviews_per_month        0
# dtype: int64
# 0   2018-10-19
# 1   2019-05-21
# 2          NaT
# 3   2019-07-05
# 4   2018-11-19
# Name: last_review, dtype: datetime64[ns]

# %%
object_columns = df.select_dtypes(include=['object']).columns
print(f"Object Colunms: {object_columns}")
# Out:
# Object Colunms: Index(['name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'room_type'],
#       dtype='object')

# %%
#object column cleaning
#import re
for col in object_columns:
    df[col] = df[col].astype(str)

def clean_text(text):
        text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
        text = text.strip().title()
        return text


for col in object_columns:
    df[col] = df[col].apply(clean_text)

df['name'] = df['name'].fillna('Unknown')
df['host_name'] = df['host_name'].fillna('Unknown')

# %%
print(df)
# Out:
#              id                                              name   host_id  \
# 0          2539                 Clean  Quiet Apt Home By The Park      2787
# 1          2595                             Skylit Midtown Castle      2845
# 2          3647                     The Village Of Harlemnew York      4632
# 3          3831                   Cozy Entire Floor Of Brownstone      4869
# 4          5022    Entire Apt Spacious Studioloft By Central Park      7192
# ...         ...                                               ...       ...
# 48890  36484665    Charming One Bedroom  Newly Renovated Rowhouse   8232441
# 48891  36485057      Affordable Room In Bushwickeast Williamsburg   6570630
# 48892  36485431           Sunny Studio At Historical Neighborhood  23492952
# 48893  36485609                43Rd St Time Squarecozy Single Bed  30985759
# 48894  36487245  Trendy Duplex In The Very Heart Of Hells Kitchen  68119814
#
# ...

# %% [markdown]
# # CLEANED DATASET

# %%
df
# Out:
#              id                                              name   host_id  \
# 0          2539                 Clean  Quiet Apt Home By The Park      2787
# 1          2595                             Skylit Midtown Castle      2845
# 2          3647                     The Village Of Harlemnew York      4632
# 3          3831                   Cozy Entire Floor Of Brownstone      4869
# 4          5022    Entire Apt Spacious Studioloft By Central Park      7192
# ...         ...                                               ...       ...
# 48890  36484665    Charming One Bedroom  Newly Renovated Rowhouse   8232441
# 48891  36485057      Affordable Room In Bushwickeast Williamsburg   6570630
# 48892  36485431           Sunny Studio At Historical Neighborhood  23492952
# 48893  36485609                43Rd St Time Squarecozy Single Bed  30985759
# 48894  36487245  Trendy Duplex In The Very Heart Of Hells Kitchen  68119814
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48895 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48895 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.to_csv(r"C:\Users\DELL\Downloads\AirBnB_clean.csv", index=False)
